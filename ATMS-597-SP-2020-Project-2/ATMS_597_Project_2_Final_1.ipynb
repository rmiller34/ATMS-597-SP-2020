# %% [markdown]
# <a href="https://colab.research.google.com/github/rmiller34/ATMS-597-SP-2020/blob/master/ATMS_597_Project_2_Final_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime

# %%
import requests

def make_request(endpoint, payload=None):
    """
    Make a request to a specific endpoint on the weather API
    passing headers and optional payload.
    
    Parameters:
        - endpoint: The endpoint of the API you want to 
                    make a GET request to.
        - payload: A dictionary of data to pass along 
                   with the request.
    
    Returns:
        Response object.
    """
    return requests.get(
        f'https://www.ncdc.noaa.gov/cdo-web/api/v2/'+endpoint,
        headers={
            'token': 'yicVcIaiwUAgtBveaBtWSaioiQvqRJRh'
        },
        params=payload
    )

# %%
# This cell will request locations. We used this to find the locationid for Champaign, IL area.
# !!!No need to run this cell again unless we want to look up a new locationid!!!

response = make_request(
    'locations', 
    {
        'datasetid' : 'GHCND', 
        'locationcategoryid' : 'CITY',
        'datacategoryid' : 'TEMP',
        'sortorder' : 'desc',
        'limit' : 1000 # max allowed
    }
)
response.json()
# Out:
# {'metadata': {'resultset': {'count': 1983, 'limit': 1000, 'offset': 1}},
#  'results': [{'datacoverage': 0.9175,
#    'id': 'CITY:ZI000004',
#    'maxdate': '1990-02-28',
#    'mindate': '1968-05-15',
#    'name': 'Masvingo, ZI'},
#   {'datacoverage': 0.8309,
#    'id': 'CITY:ZI000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1956-07-01',
#    'name': 'Harare, ZI'},
#   {'datacoverage': 0.9677,
#    'id': 'CITY:ZI000002',
#    'maxdate': '1989-06-30',
#    'mindate': '1951-07-01',
#    'name': 'Gweru, ZI'},
#   {'datacoverage': 1,
#    'id': 'CITY:ZI000001',
#    'maxdate': '1990-02-28',
#    'mindate': '1962-07-01',
#    'name': 'Bulawayo, ZI'},
#   {'datacoverage': 0.9746,
#    'id': 'CITY:ZA000007',
#    'maxdate': '1990-12-30',
#    'mindate': '1950-01-01',
#    'name': 'Ndola, ZA'},
#   {'datacoverage': 1,
#    'id': 'CITY:ZA000006',
#    'maxdate': '2014-02-12',
#    'mindate': '1956-01-01',
#    'name': 'Mongu, ZA'},
#   {'datacoverage': 0.9762,
#    'id': 'CITY:ZA000005',
#    'maxdate': '1990-12-30',
#    'mindate': '1957-06-01',
#    'name': 'Lusaka, ZA'},
#   {'datacoverage': 0.5845,
#    'id': 'CITY:ZA000004',
#    'maxdate': '2020-01-04',
#    'mindate': '1950-01-01',
#    'name': 'Livingstone, ZA'},
#   {'datacoverage': 0.6097,
#    'id': 'CITY:ZA000003',
#    'maxdate': '2017-11-24',
#    'mindate': '1950-01-01',
#    'name': 'Kasama, ZA'},
#   {'datacoverage': 0.2159,
#    'id': 'CITY:ZA000002',
#    'maxdate': '2002-08-16',
#    'mindate': '1973-01-03',
#    'name': 'Kabwe, ZA'},
#   {'datacoverage': 0.7312,
#    'id': 'CITY:ZA000001',
#    'maxdate': '2014-03-11',
#    'mindate': '1950-01-01',
#    'name': 'Chipata, ZA'},
#   {'datacoverage': 0.9887,
#    'id': 'CITY:WZ000002',
#    'maxdate': '1994-12-18',
#    'mindate': '1903-07-01',
#    'name': 'Mbabane, WZ'},
#   {'datacoverage': 0.5936,
#    'id': 'CITY:WZ000001',
#    'maxdate': '2020-01-24',
#    'mindate': '1910-02-01',
#    'name': 'Manzini, WZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:WA000002',
#    'maxdate': '2020-02-09',
#    'mindate': '1913-01-01',
#    'name': 'Windhoek, WA'},
#   {'datacoverage': 0.5213,
#    'id': 'CITY:WA000001',
#    'maxdate': '2020-02-09',
#    'mindate': '1990-02-14',
#    'name': 'Walvis Bay, WA'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000031',
#    'maxdate': '1967-12-31',
#    'mindate': '1963-05-16',
#    'name': 'Vinh Long, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000029',
#    'maxdate': '1967-12-31',
#    'mindate': '1966-11-15',
#    'name': 'Tuy Hoa, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000028',
#    'maxdate': '1967-12-31',
#    'mindate': '1967-05-01',
#    'name': 'Truc Giang, VM'},
#   {'datacoverage': 0.6918,
#    'id': 'CITY:VM000026',
#    'maxdate': '2020-02-09',
#    'mindate': '1974-09-24',
#    'name': 'Thanh Hoa, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000023',
#    'maxdate': '1967-12-31',
#    'mindate': '1967-07-01',
#    'name': 'Tan An, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000022',
#    'maxdate': '1967-12-31',
#    'mindate': '1962-09-28',
#    'name': 'Soc Trang, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000020',
#    'maxdate': '1971-06-30',
#    'mindate': '1963-05-01',
#    'name': 'Qui Nhon, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000019',
#    'maxdate': '1967-12-31',
#    'mindate': '1963-03-08',
#    'name': 'Play Cu, VM'},
#   {'datacoverage': 0.8193,
#    'id': 'CITY:VM000017',
#    'maxdate': '2020-02-09',
#    'mindate': '1956-11-08',
#    'name': 'Phan Thiet, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000016',
#    'maxdate': '1969-11-30',
#    'mindate': '1963-12-01',
#    'name': 'Nha Trang, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000015',
#    'maxdate': '1967-12-31',
#    'mindate': '1967-05-01',
#    'name': 'My Tho, VM'},
#   {'datacoverage': 0.995,
#    'id': 'CITY:VM000013',
#    'maxdate': '1969-10-20',
#    'mindate': '1967-02-01',
#    'name': 'Hue, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000010',
#    'maxdate': '2020-02-09',
#    'mindate': '1951-01-09',
#    'name': 'Ho Chi Minh City, VM'},
#   {'datacoverage': 0.979,
#    'id': 'CITY:VM000009',
#    'maxdate': '2020-02-09',
#    'mindate': '1958-12-18',
#    'name': 'Hanoi, VM'},
#   {'datacoverage': 0.9407,
#    'id': 'CITY:VM000008',
#    'maxdate': '2020-02-09',
#    'mindate': '1974-09-24',
#    'name': 'Haiphong, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000006',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-01-01',
#    'name': 'Da Nang, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000005',
#    'maxdate': '1967-12-31',
#    'mindate': '1966-10-03',
#    'name': 'Da Lat, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000004',
#    'maxdate': '1967-12-31',
#    'mindate': '1963-05-04',
#    'name': 'Can Tho, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000003',
#    'maxdate': '1967-12-31',
#    'mindate': '1966-02-09',
#    'name': 'Buon Me Thuot, VM'},
#   {'datacoverage': 1,
#    'id': 'CITY:VM000002',
#    'maxdate': '2020-02-09',
#    'mindate': '1951-01-09',
#    'name': 'Bien Hoa, VM'},
#   {'datacoverage': 0.8544,
#    'id': 'CITY:VE000019',
#    'maxdate': '2020-02-09',
#    'mindate': '1959-01-01',
#    'name': 'Valencia, VE'},
#   {'datacoverage': 0.9388,
#    'id': 'CITY:VE000017',
#    'maxdate': '2020-02-09',
#    'mindate': '1967-01-01',
#    'name': 'San Juan De Los Morros, VE'},
#   {'datacoverage': 0.974,
#    'id': 'CITY:VE000015',
#    'maxdate': '1996-12-31',
#    'mindate': '1970-01-01',
#    'name': 'San Felipe, VE'},
#   {'datacoverage': 0.9482,
#    'id': 'CITY:VE000014',
#    'maxdate': '2018-12-05',
#    'mindate': '1968-01-01',
#    'name': 'San Cristobal, VE'},
#   {'datacoverage': 0.9998,
#    'id': 'CITY:VE000013',
#    'maxdate': '1996-12-31',
#    'mindate': '1981-01-01',
#    'name': 'San Carlos, VE'},
#   {'datacoverage': 1,
#    'id': 'CITY:VE000012',
#    'maxdate': '2020-02-09',
#    'mindate': '1968-01-01',
#    'name': 'Puerto La Cruz, VE'},
#   {'datacoverage': 0.5515,
#    'id': 'CITY:VE000011',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-05-11',
#    'name': 'Puerto Ayacucho, VE'},
#   {'datacoverage': 0.8233,
#    'id': 'CITY:VE000010',
#    'maxdate': '2018-11-29',
#    'mindate': '1961-01-01',
#    'name': 'Merida, VE'},
#   {'datacoverage': 0.6683,
#    'id': 'CITY:VE000009',
#    'maxdate': '2018-11-13',
#    'mindate': '1973-05-11',
#    'name': 'Maturin, VE'},
#   {'datacoverage': 0.7481,
#    'id': 'CITY:VE000008',
#    'maxdate': '2019-12-27',
#    'mindate': '1959-01-01',
#    'name': 'Maracaibo, VE'},
#   {'datacoverage': 0.9997,
#    'id': 'CITY:VE000007',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-05-11',
#    'name': 'Guanare, VE'},
#   {'datacoverage': 0.6934,
#    'id': 'CITY:VE000006',
#    'maxdate': '2016-10-06',
#    'mindate': '1984-07-01',
#    'name': 'Cumana, VE'},
#   {'datacoverage': 0.8968,
#    'id': 'CITY:VE000005',
#    'maxdate': '2018-11-08',
#    'mindate': '1959-01-01',
#    'name': 'Coro, VE'},
#   {'datacoverage': 0.6572,
#    'id': 'CITY:VE000004',
#    'maxdate': '2016-03-28',
#    'mindate': '1973-05-11',
#    'name': 'Ciudad Bolivar, VE'},
#   {'datacoverage': 0.9892,
#    'id': 'CITY:VE000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1950-01-01',
#    'name': 'Caracas, VE'},
#   {'datacoverage': 0.9747,
#    'id': 'CITY:VE000002',
#    'maxdate': '2020-02-09',
#    'mindate': '1959-01-01',
#    'name': 'Barquisimeto, VE'},
#   {'datacoverage': 1,
#    'id': 'CITY:VE000001',
#    'maxdate': '2020-02-09',
#    'mindate': '1968-01-01',
#    'name': 'Barcelona, VE'},
#   {'datacoverage': 0.7789,
#    'id': 'CITY:UZ000013',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Urgench, UZ'},
#   {'datacoverage': 0.987,
#    'id': 'CITY:UZ000012',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Termez, UZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:UZ000011',
#    'maxdate': '2020-02-09',
#    'mindate': '1881-01-01',
#    'name': 'Tashkent, UZ'},
#   {'datacoverage': 0.999,
#    'id': 'CITY:UZ000010',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Samarkand, UZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:UZ000009',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-06-01',
#    'name': 'Nukus, UZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:UZ000008',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Navoi, UZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:UZ000007',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Namangan, UZ'},
#   {'datacoverage': 0.87,
#    'id': 'CITY:UZ000006',
#    'maxdate': '2020-02-09',
#    'mindate': '1966-01-06',
#    'name': 'Karshi, UZ'},
#   {'datacoverage': 0.617,
#    'id': 'CITY:UZ000005',
#    'maxdate': '1991-06-30',
#    'mindate': '1966-02-01',
#    'name': 'Gulistan, UZ'},
#   {'datacoverage': 0.9537,
#    'id': 'CITY:UZ000004',
#    'maxdate': '2020-02-09',
#    'mindate': '1881-04-01',
#    'name': 'Fergana, UZ'},
#   {'datacoverage': 0.6741,
#    'id': 'CITY:UZ000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1942-01-01',
#    'name': 'Dzhizak, UZ'},
#   {'datacoverage': 0.5353,
#    'id': 'CITY:UZ000002',
#    'maxdate': '2020-02-09',
#    'mindate': '1937-01-01',
#    'name': 'Bukhara, UZ'},
#   {'datacoverage': 0.8837,
#    'id': 'CITY:UZ000001',
#    'maxdate': '2020-02-08',
#    'mindate': '1936-01-01',
#    'name': 'Andizhan, UZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:UY000007',
#    'maxdate': '2016-11-01',
#    'mindate': '1964-01-01',
#    'name': 'Tacuarembo, UY'},
#   {'datacoverage': 0.9872,
#    'id': 'CITY:UY000006',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-06-30',
#    'name': 'Salto, UY'},
#   {'datacoverage': 0.9192,
#    'id': 'CITY:UY000005',
#    'maxdate': '2020-02-09',
#    'mindate': '1975-03-01',
#    'name': 'Rivera, UY'},
#   {'datacoverage': 0.8311,
#    'id': 'CITY:UY000004',
#    'maxdate': '2020-02-08',
#    'mindate': '1935-01-01',
#    'name': 'Paysandu, UY'},
#   {'datacoverage': 0.7907,
#    'id': 'CITY:UY000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-06-30',
#    'name': 'Montevideo, UY'},
#   {'datacoverage': 1,
#    'id': 'CITY:UY000002',
#    'maxdate': '2020-02-09',
#    'mindate': '1964-01-01',
#    'name': 'Melo, UY'},
#   {'datacoverage': 0.8804,
#    'id': 'CITY:UV000005',
#    'maxdate': '2020-02-09',
#    'mindate': '1967-01-01',
#    'name': 'Ouahigouya, UV'},
#   {'datacoverage': 0.9453,
#    'id': 'CITY:UV000004',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-01-01',
#    'name': 'Ouagadougou, UV'},
#   {'datacoverage': 0.93,
#    'id': 'CITY:UV000002',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-01-01',
#    'name': 'Bobo Dioulasso, UV'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560007',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-02-01',
#    'name': 'Sheridan, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560006',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-04-01',
#    'name': 'Rock Springs, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560005',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-01-01',
#    'name': 'Laramie, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560004',
#    'maxdate': '2020-02-10',
#    'mindate': '1902-03-01',
#    'name': 'Gillette, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560003',
#    'maxdate': '2020-02-09',
#    'mindate': '1890-12-03',
#    'name': 'Evanston, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560002',
#    'maxdate': '2020-02-10',
#    'mindate': '1905-05-26',
#    'name': 'Cheyenne, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US560001',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-11-01',
#    'name': 'Casper, WY US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550014',
#    'maxdate': '2020-02-10',
#    'mindate': '1895-04-01',
#    'name': 'Wausau, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550013',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-09-01',
#    'name': 'Sheboygan, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550012',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'River Falls, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550011',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Racine, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550010',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Oshkosh, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550009',
#    'maxdate': '2020-02-10',
#    'mindate': '1871-01-01',
#    'name': 'Milwaukee, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550008',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-05-01',
#    'name': 'Marinette, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550007',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Manitowoc, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550006',
#    'maxdate': '2020-02-10',
#    'mindate': '1910-11-01',
#    'name': 'Madison, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550005',
#    'maxdate': '2020-02-10',
#    'mindate': '1883-01-04',
#    'name': 'La Crosse, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550004',
#    'maxdate': '2020-02-10',
#    'mindate': '1896-05-01',
#    'name': 'Kenosha, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550003',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Janesville, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550002',
#    'maxdate': '2020-02-10',
#    'mindate': '1886-09-01',
#    'name': 'Green Bay, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US550001',
#    'maxdate': '2020-02-10',
#    'mindate': '1889-01-01',
#    'name': 'Eau Claire, WI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540009',
#    'maxdate': '2020-02-10',
#    'mindate': '1878-02-01',
#    'name': 'Wheeling, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540008',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Parkersburg, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540007',
#    'maxdate': '2020-02-10',
#    'mindate': '1873-01-01',
#    'name': 'Morgantown, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540006',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Martinsburg, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540005',
#    'maxdate': '2020-02-10',
#    'mindate': '1887-07-01',
#    'name': 'Huntington, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540004',
#    'maxdate': '2020-02-10',
#    'mindate': '1873-01-01',
#    'name': 'Fairmont, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540003',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-04-01',
#    'name': 'Charleston, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540002',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Bluefield, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US540001',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-12-01',
#    'name': 'Beckley, WV US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530025',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-03-12',
#    'name': 'Yakima, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530024',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-04-10',
#    'name': 'Wenatchee, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530023',
#    'maxdate': '2020-02-10',
#    'mindate': '1909-03-21',
#    'name': 'Walla Walla, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530022',
#    'maxdate': '2020-02-10',
#    'mindate': '1856-01-01',
#    'name': 'Vancouver, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530021',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-08-01',
#    'name': 'Tacoma, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530020',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-09-14',
#    'name': 'Sunnyside, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530019',
#    'maxdate': '2020-02-10',
#    'mindate': '1889-08-01',
#    'name': 'Spokane, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530018',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-08-01',
#    'name': 'Seattle, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530017',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Redmond, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530016',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-02-01',
#    'name': 'Pullman, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530015',
#    'maxdate': '2020-02-10',
#    'mindate': '1911-01-01',
#    'name': 'Port Angeles, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530014',
#    'maxdate': '2020-02-10',
#    'mindate': '1877-07-01',
#    'name': 'Olympia, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530013',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-10-01',
#    'name': 'Oak Harbor, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530012',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-05-01',
#    'name': 'Mount Vernon, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530011',
#    'maxdate': '2020-02-09',
#    'mindate': '1911-04-01',
#    'name': 'Moses Lake, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530010',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-02-01',
#    'name': 'Kennewick, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530009',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-08-01',
#    'name': 'Federal Way, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530008',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-02-01',
#    'name': 'Everett, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530007',
#    'maxdate': '2020-02-08',
#    'mindate': '1893-02-01',
#    'name': 'Ellensburg, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530006',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Centralia, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530005',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Bremerton, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530004',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-07-01',
#    'name': 'Bellingham, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530003',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Bellevue, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530002',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-07-01',
#    'name': 'Anacortes, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US530001',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-07-01',
#    'name': 'Aberdeen, WA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510018',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Winchester, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510017',
#    'maxdate': '2020-02-10',
#    'mindate': '1909-02-11',
#    'name': 'Virginia Beach, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510016',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Roanoke, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510015',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Richmond, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510014',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-03-03',
#    'name': 'Norfolk, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510013',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Newport News, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510012',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Lynchburg, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510011',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-09-26',
#    'name': 'Leesburg, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510010',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Harrisonburg, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510009',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-03-03',
#    'name': 'Hampton, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510008',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-04-17',
#    'name': 'Fredericksburg, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510007',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-04-01',
#    'name': 'Danville, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510006',
#    'maxdate': '2020-02-10',
#    'mindate': '1909-02-11',
#    'name': 'Chesapeake, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510005',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Charlottesville, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510004',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Centreville, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510003',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Blacksburg, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510002',
#    'maxdate': '2020-02-10',
#    'mindate': '1870-11-01',
#    'name': 'Arlington, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US510001',
#    'maxdate': '2020-02-10',
#    'mindate': '1870-11-01',
#    'name': 'Alexandria, VA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US500003',
#    'maxdate': '2020-02-10',
#    'mindate': '1904-01-01',
#    'name': 'Rutland, VT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US500002',
#    'maxdate': '2020-02-10',
#    'mindate': '1887-03-01',
#    'name': 'Montpelier, VT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US500001',
#    'maxdate': '2020-02-10',
#    'mindate': '1883-12-01',
#    'name': 'Burlington, VT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490007',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'St. George, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490006',
#    'maxdate': '2020-02-10',
#    'mindate': '1905-03-17',
#    'name': 'Salt Lake City, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490005',
#    'maxdate': '2020-02-10',
#    'mindate': '1904-06-09',
#    'name': 'Provo, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490004',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-03-01',
#    'name': 'Ogden, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490003',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Logan, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490002',
#    'maxdate': '2020-02-10',
#    'mindate': '1905-11-01',
#    'name': 'Cedar City, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US490001',
#    'maxdate': '2020-02-10',
#    'mindate': '1896-02-02',
#    'name': 'Brigham City, UT US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480070',
#    'maxdate': '2020-02-10',
#    'mindate': '1930-09-01',
#    'name': 'Wichita Falls, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480069',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-05-01',
#    'name': 'Waxahachie, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480068',
#    'maxdate': '2020-02-10',
#    'mindate': '1879-05-05',
#    'name': 'Waco, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480067',
#    'maxdate': '2020-02-10',
#    'mindate': '1904-09-01',
#    'name': 'Victoria, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480066',
#    'maxdate': '2020-02-07',
#    'mindate': '1895-05-01',
#    'name': 'Vernon, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480065',
#    'maxdate': '2020-02-09',
#    'mindate': '1905-03-01',
#    'name': 'Uvalde, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480064',
#    'maxdate': '2020-02-10',
#    'mindate': '1910-01-01',
#    'name': 'Tyler, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480063',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-08-16',
#    'name': 'The Woodlands, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480062',
#    'maxdate': '2020-02-10',
#    'mindate': '1917-09-01',
#    'name': 'Texarkana, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480061',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Sulphur Springs, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480060',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-01-01',
#    'name': 'Stephenville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480059',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-05-01',
#    'name': 'Sherman, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480058',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-04-01',
#    'name': 'San Marcos, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480057',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'San Antonio, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480056',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Round Rock, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480055',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-07-01',
#    'name': 'Rio Grande City, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480054',
#    'maxdate': '2020-02-10',
#    'mindate': '1898-11-10',
#    'name': 'Port Arthur, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480053',
#    'maxdate': '2020-02-10',
#    'mindate': '1903-04-03',
#    'name': 'Plano, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480052',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-04-01',
#    'name': 'Paris, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480051',
#    'maxdate': '2020-02-10',
#    'mindate': '1904-12-20',
#    'name': 'Palestine, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480050',
#    'maxdate': '2020-02-10',
#    'mindate': '1930-06-01',
#    'name': 'Odessa, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480049',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'New Braunfels, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480048',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-04-08',
#    'name': 'Nacogdoches, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480047',
#    'maxdate': '2020-02-10',
#    'mindate': '1905-03-10',
#    'name': 'Mount Pleasant, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480046',
#    'maxdate': '2020-02-09',
#    'mindate': '1908-09-01',
#    'name': 'Mineral Wells, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480045',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-04-13',
#    'name': 'Midland, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480044',
#    'maxdate': '2020-02-10',
#    'mindate': '1889-01-01',
#    'name': 'McAllen, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480043',
#    'maxdate': '2020-02-10',
#    'mindate': '1940-07-01',
#    'name': 'Lufkin, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480042',
#    'maxdate': '2020-02-10',
#    'mindate': '1911-03-20',
#    'name': 'Lubbock, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480041',
#    'maxdate': '2020-02-10',
#    'mindate': '1902-01-01',
#    'name': 'Longview, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480040',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-01-01',
#    'name': 'Laredo, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480039',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Lake Jackson, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480038',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-05-01',
#    'name': 'Kingsville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480037',
#    'maxdate': '2020-02-10',
#    'mindate': '1912-01-01',
#    'name': 'Killeen, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480036',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-01-02',
#    'name': 'Kerrville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480035',
#    'maxdate': '2020-02-10',
#    'mindate': '1935-02-01',
#    'name': 'Katy, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480034',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-09-01',
#    'name': 'Jacksonville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480033',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Irving, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480032',
#    'maxdate': '2020-02-10',
#    'mindate': '1903-01-01',
#    'name': 'Huntsville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480031',
#    'maxdate': '2020-02-10',
#    'mindate': '1883-04-01',
#    'name': 'Houston, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480030',
#    'maxdate': '2020-02-10',
#    'mindate': '1908-07-01',
#    'name': 'Henderson, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480029',
#    'maxdate': '2020-02-10',
#    'mindate': '1889-01-01',
#    'name': 'Harlingen, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480028',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-03-01',
#    'name': 'Greenville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480027',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-02-01',
#    'name': 'Gatesville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480026',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-01-01',
#    'name': 'Galveston, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480025',
#    'maxdate': '2020-02-09',
#    'mindate': '1893-01-01',
#    'name': 'Gainesville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480024',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Freeport, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480023',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Fort Worth, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480022',
#    'maxdate': '2020-02-10',
#    'mindate': '1912-01-01',
#    'name': 'Fort Hood, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480021',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'El Paso, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480020',
#    'maxdate': '2020-02-10',
#    'mindate': '1896-03-01',
#    'name': 'El Campo, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480019',
#    'maxdate': '2020-02-09',
#    'mindate': '1891-01-01',
#    'name': 'Eagle Pass, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480018',
#    'maxdate': '2020-02-10',
#    'mindate': '1913-06-01',
#    'name': 'Denton, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480017',
#    'maxdate': '2020-02-10',
#    'mindate': '1923-01-01',
#    'name': 'Del Rio, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480016',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Dallas, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480015',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-02',
#    'name': 'Corsicana, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480014',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Corpus Christi, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480013',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-08-16',
#    'name': 'Conroe, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480012',
#    'maxdate': '2020-02-10',
#    'mindate': '1882-05-01',
#    'name': 'College Station, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480011',
#    'maxdate': '2020-02-10',
#    'mindate': '1882-05-01',
#    'name': 'Bryan, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480010',
#    'maxdate': '2020-02-10',
#    'mindate': '1928-10-01',
#    'name': 'Brownsville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480009',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-01-01',
#    'name': 'Brenham, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480008',
#    'maxdate': '2020-02-10',
#    'mindate': '1895-08-01',
#    'name': 'Beeville, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480007',
#    'maxdate': '2020-02-10',
#    'mindate': '1901-11-01',
#    'name': 'Beaumont, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480006',
#    'maxdate': '2020-02-09',
#    'mindate': '1909-10-01',
#    'name': 'Bay City, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480005',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Austin, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480004',
#    'maxdate': '2020-02-10',
#    'mindate': '1903-12-01',
#    'name': 'Athens, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480003',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Arlington, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480002',
#    'maxdate': '2020-02-10',
#    'mindate': '1943-03-01',
#    'name': 'Amarillo, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US480001',
#    'maxdate': '2020-02-10',
#    'mindate': '1946-08-01',
#    'name': 'Abilene, TX US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470017',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-08-01',
#    'name': 'Union City, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470016',
#    'maxdate': '2020-02-10',
#    'mindate': '1890-05-01',
#    'name': 'Nashville, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470015',
#    'maxdate': '2020-02-10',
#    'mindate': '1890-05-01',
#    'name': 'Murfreesboro, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470014',
#    'maxdate': '2020-02-10',
#    'mindate': '1905-02-05',
#    'name': 'Morristown, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470013',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-05-01',
#    'name': 'Memphis, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470012',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-08-01',
#    'name': 'McMinnville, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470011',
#    'maxdate': '2020-02-10',
#    'mindate': '1890-05-01',
#    'name': 'Lebanon, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470010',
#    'maxdate': '2020-02-10',
#    'mindate': '1896-09-01',
#    'name': 'Knoxville, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470009',
#    'maxdate': '2020-02-10',
#    'mindate': '1916-12-01',
#    'name': 'Kingsport, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470008',
#    'maxdate': '2020-02-10',
#    'mindate': '1895-09-01',
#    'name': 'Johnson City, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470007',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-08-01',
#    'name': 'Jackson, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470006',
#    'maxdate': '2020-02-09',
#    'mindate': '1924-04-01',
#    'name': 'Dyersburg, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470005',
#    'maxdate': '2020-02-10',
#    'mindate': '1904-04-01',
#    'name': 'Cookeville, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470004',
#    'maxdate': '2020-02-10',
#    'mindate': '1890-05-01',
#    'name': 'Columbia, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470003',
#    'maxdate': '2020-02-10',
#    'mindate': '1890-05-01',
#    'name': 'Clarksville, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470002',
#    'maxdate': '2020-02-10',
#    'mindate': '1879-01-01',
#    'name': 'Chattanooga, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US470001',
#    'maxdate': '2020-02-10',
#    'mindate': '1888-12-01',
#    'name': 'Bristol, TN US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460009',
#    'maxdate': '2020-02-10',
#    'mindate': '1932-01-01',
#    'name': 'Yankton, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460008',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Watertown, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460007',
#    'maxdate': '2020-02-10',
#    'mindate': '1932-01-01',
#    'name': 'Sioux Falls, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460006',
#    'maxdate': '2020-02-10',
#    'mindate': '1898-01-01',
#    'name': 'Rapid City, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460005',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Pierre, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460004',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Mitchell, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460003',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Huron, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460002',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Brookings, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US460001',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Aberdeen, SD US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450012',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Sumter, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450011',
#    'maxdate': '2020-02-10',
#    'mindate': '1928-02-01',
#    'name': 'Spartanburg, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450010',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-12-01',
#    'name': 'Rock Hill, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450009',
#    'maxdate': '2020-02-10',
#    'mindate': '1898-10-01',
#    'name': 'Orangeburg, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450008',
#    'maxdate': '2020-02-10',
#    'mindate': '1912-05-01',
#    'name': 'Myrtle Beach, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450007',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Hilton Head Island, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450006',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-05-01',
#    'name': 'Greenwood, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450005',
#    'maxdate': '2020-02-10',
#    'mindate': '1884-04-01',
#    'name': 'Greenville, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450004',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-05-01',
#    'name': 'Florence, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450003',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-01-01',
#    'name': 'Columbia, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450002',
#    'maxdate': '2020-02-10',
#    'mindate': '1896-05-01',
#    'name': 'Clemson, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US450001',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Charleston, SC US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US440003',
#    'maxdate': '2020-02-10',
#    'mindate': '1910-01-01',
#    'name': 'Westerly, RI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US440002',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Providence, RI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US440001',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Newport, RI US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420024',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'York, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420023',
#    'maxdate': '2020-02-10',
#    'mindate': '1895-02-01',
#    'name': 'Williamsport, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420022',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Wilkes-Barre, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420021',
#    'maxdate': '2020-02-10',
#    'mindate': '1888-10-01',
#    'name': 'Uniontown, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420020',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'State College, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420019',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'St. Marys, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420018',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Scranton, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420017',
#    'maxdate': '2020-02-10',
#    'mindate': '1866-08-01',
#    'name': 'Reading, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420016',
#    'maxdate': '2020-02-10',
#    'mindate': '1891-01-01',
#    'name': 'Pittsburgh, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420015',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Philadelphia, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420014',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-14',
#    'name': 'Meadville, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420013',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Lebanon, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420012',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Lancaster, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420011',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-03-01',
#    'name': 'Johnstown, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420010',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-11-01',
#    'name': 'Hazleton, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420009',
#    'maxdate': '2020-02-10',
#    'mindate': '1849-04-01',
#    'name': 'Harrisburg, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420008',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-11-01',
#    'name': 'Hanover, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420007',
#    'maxdate': '2020-02-10',
#    'mindate': '1929-10-01',
#    'name': 'Erie, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420006',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Chester, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420005',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Chambersburg, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420004',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-01-01',
#    'name': 'Bloomsburg, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420003',
#    'maxdate': '2020-02-10',
#    'mindate': '1884-09-01',
#    'name': 'Bethlehem, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420002',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Altoona, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US420001',
#    'maxdate': '2020-02-10',
#    'mindate': '1884-09-01',
#    'name': 'Allentown, PA US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410017',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'St. Helens, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410016',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Salem, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410015',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-06-01',
#    'name': 'Roseburg, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410014',
#    'maxdate': '2020-02-10',
#    'mindate': '1856-01-01',
#    'name': 'Portland, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410013',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-09-01',
#    'name': 'Pendleton, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410012',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-07-01',
#    'name': 'Ontario, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410011',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-07-01',
#    'name': 'Medford, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410010',
#    'maxdate': '2020-02-10',
#    'mindate': '1909-07-01',
#    'name': 'La Grande, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410009',
#    'maxdate': '2020-02-10',
#    'mindate': '1887-05-11',
#    'name': 'Klamath Falls, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410008',
#    'maxdate': '2020-02-10',
#    'mindate': '1871-11-19',
#    'name': 'Hillsboro, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410007',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Hermiston, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410006',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-05-16',
#    'name': 'Grants Pass, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410005',
#    'maxdate': '2020-02-10',
#    'mindate': '1899-06-01',
#    'name': 'Eugene, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410004',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Corvallis, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410003',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-08-01',
#    'name': 'Coos Bay, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410002',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-07-01',
#    'name': 'City of The Dalles, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US410001',
#    'maxdate': '2020-02-10',
#    'mindate': '1901-04-01',
#    'name': 'Bend, OR US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400020',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-02-01',
#    'name': 'Woodward, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400019',
#    'maxdate': '2020-02-10',
#    'mindate': '1889-01-01',
#    'name': 'Tulsa, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400018',
#    'maxdate': '2020-02-09',
#    'mindate': '1900-01-01',
#    'name': 'Tahlequah, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400017',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Stillwater, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400016',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Shawnee, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400015',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Ponca City, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400014',
#    'maxdate': '2020-02-04',
#    'mindate': '1910-01-01',
#    'name': 'Okmulgee, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400013',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Oklahoma City, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400012',
#    'maxdate': '2020-02-09',
#    'mindate': '1895-04-01',
#    'name': 'Muskogee, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400011',
#    'maxdate': '2020-02-09',
#    'mindate': '1899-04-01',
#    'name': 'McAlester, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400010',
#    'maxdate': '2020-02-10',
#    'mindate': '1870-04-01',
#    'name': 'Lawton, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400009',
#    'maxdate': '2020-02-09',
#    'mindate': '1893-05-19',
#    'name': 'Guymon, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400008',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-02-01',
#    'name': 'Enid, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400007',
#    'maxdate': '2020-02-09',
#    'mindate': '1904-05-01',
#    'name': 'Elk City, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400006',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-05-15',
#    'name': 'Durant, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400005',
#    'maxdate': '2020-02-10',
#    'mindate': '1901-01-01',
#    'name': 'Chickasha, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400004',
#    'maxdate': '2020-02-10',
#    'mindate': '1920-01-01',
#    'name': 'Bartlesville, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400003',
#    'maxdate': '2020-02-10',
#    'mindate': '1901-07-01',
#    'name': 'Ardmore, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400002',
#    'maxdate': '2020-02-10',
#    'mindate': '1903-05-01',
#    'name': 'Altus, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US400001',
#    'maxdate': '2020-02-10',
#    'mindate': '1901-01-01',
#    'name': 'Ada, OK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390029',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Zanesville, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390028',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Youngstown, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390027',
#    'maxdate': '2020-02-09',
#    'mindate': '1893-01-01',
#    'name': 'Wooster, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390026',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-04-01',
#    'name': 'Urbana, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390025',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-02-01',
#    'name': 'Toledo, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390024',
#    'maxdate': '2020-02-10',
#    'mindate': '1878-02-01',
#    'name': 'Steubenville, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390023',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-04-01',
#    'name': 'Sandusky, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390022',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Salem, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390021',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-02-01',
#    'name': 'Portsmouth, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390020',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Newark, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390019',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-06-01',
#    'name': 'New Philadelphia, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390018',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-07-02',
#    'name': 'Mentor, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390017',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-12-01',
#    'name': 'Marion, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390016',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Mansfield, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390015',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Lima, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390014',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-09-10',
#    'name': 'Delaware, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390013',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Defiance, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390012',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Dayton, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390011',
#    'maxdate': '2020-02-10',
#    'mindate': '1897-04-15',
#    'name': 'Columbus, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390010',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Cleveland, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390009',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Cincinnati, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390008',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Chillicothe, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390007',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Canton, OH US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US390006',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Cambridge, OH US'},
# ...
#   {'datacoverage': 1,
#    'id': 'CITY:US040012',
#    'maxdate': '2020-02-10',
#    'mindate': '1898-05-01',
#    'name': 'Prescott, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040011',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Phoenix, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040010',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Payson, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040009',
#    'maxdate': '2020-02-10',
#    'mindate': '1892-12-01',
#    'name': 'Nogales, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040008',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Mesa, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040007',
#    'maxdate': '2020-02-10',
#    'mindate': '1967-09-01',
#    'name': 'Lake Havasu City, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040006',
#    'maxdate': '2020-02-10',
#    'mindate': '1901-05-12',
#    'name': 'Kingman, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040005',
#    'maxdate': '2020-02-10',
#    'mindate': '1916-06-01',
#    'name': 'Green Valley, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040004',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Flagstaff, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040003',
#    'maxdate': '2020-02-10',
#    'mindate': '1903-12-01',
#    'name': 'Douglas, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040002',
#    'maxdate': '2020-02-10',
#    'mindate': '1898-06-01',
#    'name': 'Casa Grande, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US040001',
#    'maxdate': '2020-02-10',
#    'mindate': '1948-07-01',
#    'name': 'Bullhead City, AZ US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US020005',
#    'maxdate': '2020-02-09',
#    'mindate': '1931-01-01',
#    'name': 'Seward, AK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US020004',
#    'maxdate': '2020-02-10',
#    'mindate': '1908-01-01',
#    'name': 'Nome, AK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US020003',
#    'maxdate': '2020-02-10',
#    'mindate': '1915-11-01',
#    'name': 'Juneau, AK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US020002',
#    'maxdate': '2020-02-10',
#    'mindate': '1904-09-01',
#    'name': 'Fairbanks, AK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US020001',
#    'maxdate': '2020-02-10',
#    'mindate': '1916-02-01',
#    'name': 'Anchorage, AK US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010019',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-01-01',
#    'name': 'Tuscaloosa, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010018',
#    'maxdate': '2020-02-09',
#    'mindate': '1908-06-01',
#    'name': 'Troy, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010017',
#    'maxdate': '2020-02-10',
#    'mindate': '1888-02-01',
#    'name': 'Talladega, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010016',
#    'maxdate': '2020-02-10',
#    'mindate': '1895-01-01',
#    'name': 'Selma, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010015',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Montgomery, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010014',
#    'maxdate': '2020-02-10',
#    'mindate': '1938-01-01',
#    'name': 'Mobile, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010013',
#    'maxdate': '2020-02-09',
#    'mindate': '1891-10-01',
#    'name': 'Jasper, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010012',
#    'maxdate': '2020-02-10',
#    'mindate': '1894-02-01',
#    'name': 'Huntsville, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010011',
#    'maxdate': '2020-02-09',
#    'mindate': '1893-07-01',
#    'name': 'Gadsden, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010010',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Fort Payne, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010009',
#    'maxdate': '2020-02-10',
#    'mindate': '1893-01-01',
#    'name': 'Florence, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010008',
#    'maxdate': '2019-12-31',
#    'mindate': '1892-06-01',
#    'name': 'Eufaula, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010007',
#    'maxdate': '2020-02-10',
#    'mindate': '1902-05-01',
#    'name': 'Enterprise, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010006',
#    'maxdate': '2020-02-10',
#    'mindate': '1933-07-02',
#    'name': 'Dothan, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010005',
#    'maxdate': '2020-02-10',
#    'mindate': '1907-08-01',
#    'name': 'Cullman, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010004',
#    'maxdate': '2020-02-10',
#    'mindate': '1900-10-01',
#    'name': 'Birmingham, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010003',
#    'maxdate': '2020-02-10',
#    'mindate': '1906-04-01',
#    'name': 'Auburn, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010002',
#    'maxdate': '2020-02-10',
#    'mindate': '1903-02-01',
#    'name': 'Anniston, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US010001',
#    'maxdate': '2020-02-10',
#    'mindate': '1895-11-01',
#    'name': 'Alexander City, AL US'},
#   {'datacoverage': 1,
#    'id': 'CITY:US000001',
#    'maxdate': '2020-02-10',
#    'mindate': '1870-11-01',
#    'name': 'Washington D.C., US'},
#   {'datacoverage': 0.8014,
#    'id': 'CITY:UP000025',
#    'maxdate': '2020-02-09',
#    'mindate': '1938-01-01',
#    'name': 'Zhytomyra, UP'},
#   {'datacoverage': 0.8709,
#    'id': 'CITY:UP000024',
#    'maxdate': '2009-06-17',
#    'mindate': '1936-01-01',
#    'name': 'Zaporiyhzhya, UP'},
#   {'datacoverage': 0.9832,
#    'id': 'CITY:UP000023',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Vinnytsya, UP'},
#   {'datacoverage': 0.9766,
#    'id': 'CITY:UP000022',
#    'maxdate': '2020-02-09',
#    'mindate': '1946-05-01',
#    'name': 'Uzhhorod, UP'},
#   {'datacoverage': 0.7201,
#    'id': 'CITY:UP000021',
#    'maxdate': '2020-02-09',
#    'mindate': '1944-05-01',
#    'name': "Ternopil', UP"},
#   {'datacoverage': 0.7977,
#    'id': 'CITY:UP000020',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Sumy, UP'},
#   {'datacoverage': 0.7282,
#    'id': 'CITY:UP000019',
#    'maxdate': '2009-06-17',
#    'mindate': '1959-07-04',
#    'name': "Simferopol', UP"},
#   {'datacoverage': 0.7599,
#    'id': 'CITY:UP000018',
#    'maxdate': '2020-02-09',
#    'mindate': '1959-01-01',
#    'name': 'Rivne, UP'},
#   {'datacoverage': 0.9713,
#    'id': 'CITY:UP000017',
#    'maxdate': '2020-02-09',
#    'mindate': '1900-01-01',
#    'name': 'Poltava, UP'},
#   {'datacoverage': 0.9698,
#    'id': 'CITY:UP000016',
#    'maxdate': '2020-02-09',
#    'mindate': '1894-01-01',
#    'name': 'Odesa, UP'},
#   {'datacoverage': 0.9411,
#    'id': 'CITY:UP000015',
#    'maxdate': '2012-12-31',
#    'mindate': '1881-01-01',
#    'name': 'Mykolayiv, UP'},
#   {'datacoverage': 0.9896,
#    'id': 'CITY:UP000014',
#    'maxdate': '2014-07-06',
#    'mindate': '1881-01-01',
#    'name': "Luhans'k, UP"},
#   {'datacoverage': 0.9389,
#    'id': 'CITY:UP000013',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': "L'viv, UP"},
#   {'datacoverage': 0.9891,
#    'id': 'CITY:UP000012',
#    'maxdate': '2020-02-09',
#    'mindate': '1881-01-01',
#    'name': 'Kyiv, UP'},
#   {'datacoverage': 0.8655,
#    'id': 'CITY:UP000011',
#    'maxdate': '2009-06-17',
#    'mindate': '1959-07-02',
#    'name': "Kovel', UP"},
#   {'datacoverage': 0.9211,
#    'id': 'CITY:UP000010',
#    'maxdate': '2020-02-09',
#    'mindate': '1949-07-31',
#    'name': 'Kirovohrad, UP'},
#   {'datacoverage': 0.89,
#    'id': 'CITY:UP000009',
#    'maxdate': '2020-02-09',
#    'mindate': '1955-01-29',
#    'name': "Khmel'nyts'kyz, UP"},
#   {'datacoverage': 0.693,
#    'id': 'CITY:UP000008',
#    'maxdate': '2020-02-09',
#    'mindate': '1879-02-06',
#    'name': 'Kherson, UP'},
#   {'datacoverage': 0.8814,
#    'id': 'CITY:UP000007',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-01-01',
#    'name': 'Kharkiv, UP'},
#   {'datacoverage': 0.7952,
#    'id': 'CITY:UP000006',
#    'maxdate': '2009-06-17',
#    'mindate': '1941-01-02',
#    'name': "Ivano-frankivs'k, UP"},
#   {'datacoverage': 0.9428,
#    'id': 'CITY:UP000005',
#    'maxdate': '2013-12-30',
#    'mindate': '1949-07-28',
#    'name': "Donets'k, UP"},
#   {'datacoverage': 0.9492,
#    'id': 'CITY:UP000004',
#    'maxdate': '2020-02-09',
#    'mindate': '1936-12-31',
#    'name': "Dnipropetrovs'k, UP"},
#   {'datacoverage': 0.9524,
#    'id': 'CITY:UP000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1941-03-01',
#    'name': 'Chernivtsi, UP'},
#   {'datacoverage': 0.8683,
#    'id': 'CITY:UP000002',
#    'maxdate': '2009-06-17',
#    'mindate': '1936-01-01',
#    'name': 'Chernihiv, UP'},
#   {'datacoverage': 0.8686,
#    'id': 'CITY:UP000001',
#    'maxdate': '2009-06-17',
#    'mindate': '1936-01-01',
#    'name': 'Cherkasy, UP'},
#   {'datacoverage': 0.9999,
#    'id': 'CITY:UK000012',
#    'maxdate': '2012-12-31',
#    'mindate': '1959-12-31',
#    'name': 'Southampton, UK'},
#   {'datacoverage': 0.9839,
#    'id': 'CITY:UK000011',
#    'maxdate': '2017-12-31',
#    'mindate': '1882-12-31',
#    'name': 'Sheffield, UK'},
#   {'datacoverage': 0.9979,
#    'id': 'CITY:UK000010',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-01-01',
#    'name': 'Manchester, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000009',
#    'maxdate': '2020-02-09',
#    'mindate': '1904-02-01',
#    'name': 'London, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000008',
#    'maxdate': '2004-12-31',
#    'mindate': '1920-12-31',
#    'name': 'Liverpool, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000007',
#    'maxdate': '2017-12-31',
#    'mindate': '1910-12-31',
#    'name': 'Leeds, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000006',
#    'maxdate': '2017-12-31',
#    'mindate': '1914-01-01',
#    'name': 'Glasgow, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000005',
#    'maxdate': '2017-12-31',
#    'mindate': '1959-12-31',
#    'name': 'Edinburgh, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000004',
#    'maxdate': '2020-02-09',
#    'mindate': '1959-12-31',
#    'name': 'Dundee, UK'},
#   {'datacoverage': 1,
#    'id': 'CITY:UK000002',
#    'maxdate': '2017-12-31',
#    'mindate': '1880-12-31',
#    'name': 'Birmingham, UK'},
#   {'datacoverage': 0.9998,
#    'id': 'CITY:UK000001',
#    'maxdate': '2020-02-09',
#    'mindate': '1939-08-08',
#    'name': 'Belfast, UK'},
#   {'datacoverage': 0.9553,
#    'id': 'CITY:UG000003',
#    'maxdate': '1986-12-30',
#    'mindate': '1955-01-01',
#    'name': 'Jinja, UG'},
#   {'datacoverage': 0.968,
#    'id': 'CITY:UG000002',
#    'maxdate': '1986-12-15',
#    'mindate': '1926-01-01',
#    'name': 'Gulu, UG'},
#   {'datacoverage': 0.9567,
#    'id': 'CITY:UG000001',
#    'maxdate': '1976-12-31',
#    'mindate': '1971-04-01',
#    'name': 'Arua, UG'},
#   {'datacoverage': 0.4746,
#    'id': 'CITY:TZ000019',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-01-01',
#    'name': 'Zanzibar, TZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:TZ000017',
#    'maxdate': '2020-02-09',
#    'mindate': '1951-08-01',
#    'name': 'Tabora, TZ'},
#   {'datacoverage': 0.4171,
#    'id': 'CITY:TZ000015',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-01-01',
#    'name': 'Songea, TZ'},
#   {'datacoverage': 0.6966,
#    'id': 'CITY:TZ000012',
#    'maxdate': '2020-02-09',
#    'mindate': '1950-01-01',
#    'name': 'Mwanza, TZ'},
#   {'datacoverage': 0.9997,
#    'id': 'CITY:TZ000011',
#    'maxdate': '1989-12-31',
#    'mindate': '1950-01-01',
#    'name': 'Musoma, TZ'},
#   {'datacoverage': 0.6211,
#    'id': 'CITY:TZ000010',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-01-01',
#    'name': 'Mtwara, TZ'},
#   {'datacoverage': 0.9999,
#    'id': 'CITY:TZ000009',
#    'maxdate': '1989-12-31',
#    'mindate': '1950-01-01',
#    'name': 'Moshi, TZ'},
#   {'datacoverage': 0.999,
#    'id': 'CITY:TZ000005',
#    'maxdate': '1990-03-31',
#    'mindate': '1960-01-01',
#    'name': 'Iringa, TZ'},
#   {'datacoverage': 1,
#    'id': 'CITY:TZ000004',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-01-01',
#    'name': 'Dodoma, TZ'},
#   {'datacoverage': 0.7584,
#    'id': 'CITY:TZ000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-01-01',
#    'name': 'Dar es Salaam, TZ'},
#   {'datacoverage': 0.9979,
#    'id': 'CITY:TZ000002',
#    'maxdate': '1989-12-31',
#    'mindate': '1950-01-01',
#    'name': 'Bukoba, TZ'},
#   {'datacoverage': 0.9998,
#    'id': 'CITY:TZ000001',
#    'maxdate': '1989-12-31',
#    'mindate': '1959-02-01',
#    'name': 'Arusha, TZ'},
#   {'datacoverage': 0.9447,
#    'id': 'CITY:TX000003',
#    'maxdate': '2020-02-09',
#    'mindate': '1933-01-06',
#    'name': 'Turkmenbashi, TX'},
#   {'datacoverage': 0.9293,
#    'id': 'CITY:TX000002',
#    'maxdate': '1991-06-30',
#    'mindate': '1959-01-01',
#    'name': 'Mary, TX'},
#   {'datacoverage': 0.9166,
#    'id': 'CITY:TX000001',
#    'maxdate': '2020-02-09',
#    'mindate': '1898-07-17',
#    'name': 'Ashgabat, TX'},
#   {'datacoverage': 0.846,
#    'id': 'CITY:TU000057',
#    'maxdate': '2020-02-09',
#    'mindate': '1957-07-04',
#    'name': 'Zonguldak, TU'},
#   {'datacoverage': 0.9296,
#    'id': 'CITY:TU000056',
#    'maxdate': '2020-02-09',
#    'mindate': '1998-02-06',
#    'name': 'Yozgat, TU'},
#   {'datacoverage': 0.9374,
#    'id': 'CITY:TU000055',
#    'maxdate': '2020-02-09',
#    'mindate': '1938-05-01',
#    'name': 'Van, TU'},
#   {'datacoverage': 0.8962,
#    'id': 'CITY:TU000054',
#    'maxdate': '2020-02-09',
#    'mindate': '1963-01-17',
#    'name': 'Usak, TU'},
#   {'datacoverage': 0.9946,
#    'id': 'CITY:TU000052',
#    'maxdate': '2020-02-09',
#    'mindate': '2002-03-29',
#    'name': 'Tokat, TU'},
#   {'datacoverage': 0.9054,
#    'id': 'CITY:TU000051',
#    'maxdate': '2020-02-09',
#    'mindate': '1963-01-17',
#    'name': 'Tekirdag, TU'},
#   {'datacoverage': 0.915,
#    'id': 'CITY:TU000050',
#    'maxdate': '2020-02-09',
#    'mindate': '1929-02-01',
#    'name': 'Sivas, TU'},
#   {'datacoverage': 0.4189,
#    'id': 'CITY:TU000049',
#    'maxdate': '2020-02-09',
#    'mindate': '1963-01-15',
#    'name': 'Siirt, TU'},
#   {'datacoverage': 0.7047,
#    'id': 'CITY:TU000048',
#    'maxdate': '2020-02-09',
#    'mindate': '1951-05-08',
#    'name': 'Samsun, TU'},
#   {'datacoverage': 0.6815,
#    'id': 'CITY:TU000047',
#    'maxdate': '2020-02-09',
#    'mindate': '2003-11-21',
#    'name': 'Sakarya, TU'},
#   {'datacoverage': 0.8818,
#    'id': 'CITY:TU000046',
#    'maxdate': '2020-02-09',
#    'mindate': '1927-03-09',
#    'name': 'Rize, TU'},
#   {'datacoverage': 0.9372,
#    'id': 'CITY:TU000044',
#    'maxdate': '2020-02-09',
#    'mindate': '2001-07-05',
#    'name': 'Nigde, TU'},
#   {'datacoverage': 0.5301,
#    'id': 'CITY:TU000043',
#    'maxdate': '2020-02-09',
#    'mindate': '2003-11-21',
#    'name': 'Nevsehir, TU'},
#   {'datacoverage': 0.4271,
#    'id': 'CITY:TU000042',
#    'maxdate': '2020-02-09',
#    'mindate': '2003-11-22',
#    'name': 'Mus, TU'},
#   {'datacoverage': 0.2609,
#    'id': 'CITY:TU000041',
#    'maxdate': '2020-02-09',
#    'mindate': '1974-08-20',
#    'name': 'Mersin, TU'},
#   {'datacoverage': 0.3295,
#    'id': 'CITY:TU000038',
#    'maxdate': '2008-12-31',
#    'mindate': '2004-07-13',
#    'name': 'Malatya, TU'},
#   {'datacoverage': 0.9141,
#    'id': 'CITY:TU000037',
#    'maxdate': '2020-02-09',
#    'mindate': '2003-03-30',
#    'name': 'Kutahya, TU'},
#   {'datacoverage': 0.7595,
#    'id': 'CITY:TU000036',
#    'maxdate': '2020-02-09',
#    'mindate': '1950-01-02',
#    'name': 'Konya, TU'},
#   {'datacoverage': 0.4639,
#    'id': 'CITY:TU000034',
#    'maxdate': '2020-02-09',
#    'mindate': '1963-01-13',
#    'name': 'Kirsehir, TU'},
#   {'datacoverage': 0.9448,
#    'id': 'CITY:TU000031',
#    'maxdate': '2020-02-09',
#    'mindate': '1930-01-01',
#    'name': 'Kastamonu, TU'},
#   {'datacoverage': 0.4488,
#    'id': 'CITY:TU000030',
#    'maxdate': '2020-02-09',
#    'mindate': '1963-03-01',
#    'name': 'Kars, TU'},
#   {'datacoverage': 0.7153,
#    'id': 'CITY:TU000029',
#    'maxdate': '2020-02-09',
#    'mindate': '1998-05-21',
#    'name': 'Kahramanmaras, TU'},
#   {'datacoverage': 1,
#    'id': 'CITY:TU000028',
#    'maxdate': '2020-02-09',
#    'mindate': '1950-01-15',
#    'name': 'Izmir, TU'},
#   {'datacoverage': 1,
#    'id': 'CITY:TU000027',
#    'maxdate': '2020-02-09',
#    'mindate': '1929-01-01',
#    'name': 'Istanbul, TU'},
#   {'datacoverage': 0.9536,
#    'id': 'CITY:TU000026',
#    'maxdate': '2020-02-09',
#    'mindate': '1929-01-01',
#    'name': 'Isparta, TU'},
#   {'datacoverage': 0.2105,
#    'id': 'CITY:TU000025',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-01-01',
#    'name': 'Hakkari, TU'},
#   {'datacoverage': 0.4203,
#    'id': 'CITY:TU000024',
#    'maxdate': '2020-02-09',
#    'mindate': '1973-01-01',
#    'name': 'Giresun, TU'}]}

# %%
# This cell will request stations. We used this to find the stationid for Rantoul, IL station.
# !!!No need to run this cell again unless we want to look up a new stationid!!!

response = make_request(
    'stations', 
    {
        'datasetid' : 'GHCND',
        'locationid' : 'CITY:US170004', 
        'datacategoryid' : 'TEMP',
        'limit' : 1000 # max allowed
    }
)
response.json()

# %%
# Create lists containing the beginning and end of years we want to loop over.

yearstoget = np.arange(1949,2000)
currentlist = []
endlist = []
for i in yearstoget:
    currentlist.append(datetime.date(i, 1, 1))
    endlist.append(datetime.date(i, 12, 31))

# %%
# This cell will request the data

resultsmax = [] # get an empty list to fill with data
numloops = np.arange(len(currentlist)) # fill a numpy array with the length of the list of years we want

#Start the loop over the years we want
for i in numloops:
    print(currentlist[i])
    current = currentlist[i] # set current to the beginning of the year in our loop
    end = endlist[i] # set end to the end of the year in our loop
    # update the cell with status information
    #display.clear_output(wait=True)
    #display.display(f'Gathering data for {str(current)}')
    response = make_request(
        'data', 
        {
            'datasetid' : 'GHCND', # Global Historical Climatology Network - Daily (GHCND) dataset
            'datatypeid' : 'TMAX',
            'stationid' : 'GHCND:USW00014806',
            'startdate' : current,
            'enddate' : end,
            'units' : 'metric',
            'limit' : 1000 # max allowed
        }
    )
    response.json()
    resultsmax.extend(response.json()['results']) # put the data in the results list
# Out:
# 1949-01-01
# 1950-01-01
# 1951-01-01
# 1952-01-01
# 1953-01-01
# 1954-01-01
# 1955-01-01
# 1956-01-01
# 1957-01-01
# 1958-01-01
# 1959-01-01
# 1960-01-01
# 1961-01-01
# 1962-01-01
# 1963-01-01
# 1964-01-01
# 1965-01-01
# 1966-01-01
# 1967-01-01
# 1968-01-01
# 1969-01-01
# 1970-01-01
# 1971-01-01
# 1972-01-01
# 1973-01-01
# 1974-01-01
# 1975-01-01
# 1976-01-01
# 1977-01-01
# 1978-01-01
# 1979-01-01
# 1980-01-01
# 1981-01-01
# 1982-01-01
# 1983-01-01
# 1984-01-01
# 1985-01-01
# 1986-01-01
# 1987-01-01
# 1988-01-01
# 1989-01-01
# 1990-01-01
# 1991-01-01
# 1992-01-01
# 1993-01-01
# 1994-01-01
# 1995-01-01
# 1996-01-01
# 1997-01-01
# 1998-01-01
# 1999-01-01

# %%
# This cell will request the data

resultsmin = [] # get an empty list to fill with data
numloops = np.arange(len(currentlist)) # fill a numpy array with the length of the list of years we want

#Start the loop over the years we want
for i in numloops:
    print(currentlist[i])
    current = currentlist[i] # set current to the beginning of the year in our loop
    end = endlist[i] # set end to the end of the year in our loop
    # update the cell with status information
    #display.clear_output(wait=True)
    #display.display(f'Gathering data for {str(current)}')
    response = make_request(
        'data', 
        {
            'datasetid' : 'GHCND', # Global Historical Climatology Network - Daily (GHCND) dataset
            'datatypeid' : 'TMIN',
            'stationid' : 'GHCND:USW00014806',
            'startdate' : current,
            'enddate' : end,
            'units' : 'metric',
            'limit' : 1000 # max allowed
        }
    )
    response.json()
    resultsmin.extend(response.json()['results']) # put the data in the results list
# Out:
# 1949-01-01
# 1950-01-01
# 1951-01-01
# 1952-01-01
# 1953-01-01
# 1954-01-01
# 1955-01-01
# 1956-01-01
# 1957-01-01
# 1958-01-01
# 1959-01-01
# 1960-01-01
# 1961-01-01
# 1962-01-01
# 1963-01-01
# 1964-01-01
# 1965-01-01
# 1966-01-01
# 1967-01-01
# 1968-01-01
# 1969-01-01
# 1970-01-01
# 1971-01-01
# 1972-01-01
# 1973-01-01
# 1974-01-01
# 1975-01-01
# 1976-01-01
# 1977-01-01
# 1978-01-01
# 1979-01-01
# 1980-01-01
# 1981-01-01
# 1982-01-01
# 1983-01-01
# 1984-01-01
# 1985-01-01
# 1986-01-01
# 1987-01-01
# 1988-01-01
# 1989-01-01
# 1990-01-01
# 1991-01-01
# 1992-01-01
# 1993-01-01
# 1994-01-01
# 1995-01-01
# 1996-01-01
# 1997-01-01
# 1998-01-01
# 1999-01-01

# %%
len(resultsmax) # check the length of the results list to make sure we have the correct number of days
# Out:
# 3640

# %%
# Put the results in a pandas dataframe
dfmax = pd.DataFrame(resultsmax)
dfmax.tail()
dfmin = pd.DataFrame(resultsmin)
dfmin.tail()
# Out:
#                       date datatype            station attributes  value
# 18137  1999-12-27T00:00:00     TMIN  GHCND:USW00014806   ,,0,0700  -14.4
# 18138  1999-12-28T00:00:00     TMIN  GHCND:USW00014806   ,,0,0700  -17.2
# 18139  1999-12-29T00:00:00     TMIN  GHCND:USW00014806   ,,0,0700   -7.2
# 18140  1999-12-30T00:00:00     TMIN  GHCND:USW00014806   ,,0,0700   -4.4
# 18141  1999-12-31T00:00:00     TMIN  GHCND:USW00014806   ,,0,0700   -7.2

# %%
###Rylan's code for getting Yearly Average Temperature goes here. ###

# %%
df.to_csv('Rantoul.csv')

# %%
#Clean up the TMAX data frame
#dfmax = pd.DataFrame(resultsmax)  # Uncomment to reset the data frame in case you mess up 

dfmax['date']= pd.to_datetime(dfmax['date']) 
dfmax.index = dfmax['date']
 
del dfmax['datatype']
del dfmax['station']
del dfmax['attributes']
#del df['date']
 
dfmax.columns = ['date','TMAX']
dfmax.to_csv('project2_data_TMAX')
 
dfmax.head()
# Out:
#                  date  TMAX
# date
# 1949-01-01 1949-01-01  -0.6
# 1949-01-02 1949-01-02   2.8
# 1949-01-03 1949-01-03   4.4
# 1949-01-04 1949-01-04  10.0
# 1949-01-05 1949-01-05   4.4

# %%
#Clean up the TMIN data frame
#dfmin = pd.DataFrame(resultsmin)  # Uncomment to reset the data frame in case you mess up

dfmin['date']= pd.to_datetime(dfmin['date']) 
dfmin.index = dfmin['date']
 
del dfmin['datatype']
del dfmin['station']
del dfmin['attributes']
#del df['date']
 
dfmin.columns = ['date','TMIN']
dfmin.to_csv('project2_data_TMIN')
 
dfmin.head()
# Out:
#                  date  TMIN
# date
# 1949-01-01 1949-01-01  -7.8
# 1949-01-02 1949-01-02  -3.3
# 1949-01-03 1949-01-03   1.7
# 1949-01-04 1949-01-04   4.4
# 1949-01-05 1949-01-05  -2.8

# %%
dfboth = pd.merge(dfmax, dfmin, left_index=True, right_index=True)
del dfboth['date_x']
del dfboth['date_y']
dfboth['TAVG'] = (dfboth['TMAX']+dfboth['TMIN'])/2.0
del dfboth['TMAX']
del dfboth['TMIN']
dfboth
# Out:
#             TAVG
# date
# 1949-01-01 -4.20
# 1949-01-02 -0.25
# 1949-01-03  3.05
# 1949-01-04  7.20
# 1949-01-05  0.80
# ...          ...
# 1999-12-27 -7.50
# 1999-12-28 -3.30
# 1999-12-29 -3.05
# 1999-12-30 -1.10
# 1999-12-31  4.20
#
# [18077 rows x 1 columns]

# %%
# Choose the frequency that you want averages for
avgfreq = 'Y'
#avgfreq = 'M'
#avgfreq = 'W'
if avgfreq == 'Y':
    headername = 'Yearly Average Temperature'
    numperyear = 1
if avgfreq == 'M':
    headername = 'Monthly Average Temperature'
    numperyear = 12
if avgfreq == 'W':
    headername = 'Weekly Average Temperature'


df = dfboth.groupby(pd.Grouper(freq=avgfreq)).mean()
df.index = pd.to_datetime(df.index, format='%Y-%m-%d').year
df.columns = [headername]
df['Anomalies'] = (df[headername] - df[headername].mean())
df
# Out:
#       Yearly Average Temperature  Anomalies
# date
# 1949                   11.943014   1.130651
# 1950                    9.939863  -0.872500
# 1951                    9.998356  -0.814007
# 1952                   11.645492   0.833129
# 1953                   12.229945   1.417582
# 1954                   12.244918   1.432555
# 1955                   11.388187   0.575824
# 1956                   11.619399   0.807036
# 1957                   10.825890   0.013528
# 1958                    9.640411  -1.171952
# 1959                   10.565068  -0.247294
# 1960                    9.581694  -1.230669
# 1961                   10.766758  -0.045605
# 1962                   10.012055  -0.800308
# 1963                    4.283264  -6.529098
# 1964                   10.778962  -0.033401
# 1965                   11.481096   0.668733
# 1966                   11.050694   0.238332
# 1967                   11.075138   0.262775
# 1968                   10.769653  -0.042710
# 1969                   10.865871   0.053508
# 1970                   11.268320   0.455957
# 1971                   12.076316   1.263953
# 1972                   11.137190   0.324827
# 1973                   12.045317   1.232954
# 1974                   10.839660   0.027297
# 1975                   10.698889  -0.113474
# 1976                    9.881127  -0.931236
# 1977                   10.143840  -0.668523
# 1978                   10.089847  -0.722516
# 1979                   11.240506   0.428143
# 1980                   10.203771  -0.608592
# 1981                   10.276184  -0.536179
# 1982                    9.921096  -0.891267
# 1983                   11.186538   0.374176
# 1984                   10.751796  -0.060567
# 1985                   10.750556  -0.061807
# 1986                   11.469861   0.657498
# 1987                   15.488745   4.676382
# 1988                   10.358219  -0.454144
# 1989                    9.522865  -1.289498
# 1990                   11.172192   0.359829
# 1991                   12.347397   1.535034
# 1992                   10.807576  -0.004787
# 1993                   10.563056  -0.249307
# 1994                   10.565342  -0.247020
# 1995                   10.938874   0.126511
# 1996                    9.592760  -1.219603
# 1997                    9.962637  -0.849726
# 1998                   12.185537   1.373174
# 1999                   11.238767   0.426404

# %%
# A cell for quickly cheking the min and max anomalies for color scale purposes.

mintemp = (min(df['Anomalies'].values))
maxtemp = (max(df['Anomalies'].values))
vmin = int(mintemp) 
vmax = int(maxtemp)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

#df['Anomalies'].values
ax = plt.matshow(df['Anomalies'][np.newaxis,:], cmap='coolwarm', aspect = 'auto', vmin = vmin , vmax = vmax)
ax.axes.get_yaxis().set_visible(False)
#ax.axes.set_xticklabels(yearstoget[0::10])
ax.axes.tick_params(axis="x", bottom=True, top=False, labelbottom=True, labeltop=False)
#ax.axes.set_xlim(left = 0, right = len(yearstoget)-1)

#x_pos = np.arange(len(df['Anomalies']))
#plt.xticks(yearstoget)
ax2 = plt.twinx()
ax2.plot(np.arange(0,(len(yearstoget))*numperyear), df[headername], color = 'black')
ax2.plot(np.arange(0,(len(yearstoget))*numperyear), df[headername], 'ko')
ax2.axes.set_ylabel('Average annual \n maximum temperature \n (deg C)')

plt.show()
